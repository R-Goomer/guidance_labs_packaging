# %% [markdown]
# # Deploy Blog
# Run each cell top to bottom. That's it.

# %%
# 1. Rebuild index.html from posts/
# !node build.js

# 2. Stage everything
# !git add -A
# !git status

# 3. Commit with today's date as the message
import datetime
msg = f"deploy {datetime.date.today()}"
# !git commit -m "{msg}"

# 4. Push to main
# !git push origin main
# Out:
# ✓ index.html rebuilt — 1 post(s) listed.
