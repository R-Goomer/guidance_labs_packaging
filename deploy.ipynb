# %% [markdown]
# # Deploy Blog
# Run each cell top to bottom. That's it.

# %%
# create a blank html file with date and random word in the name
import datetime
import random
import string

def create_blank_html_file():
    # Get the current date
    current_date = datetime.datetime.now().strftime("%Y-%m-%d")
    
    # Generate a random word
    random_word = ''.join(random.choices(string.ascii_lowercase, k=5))
    
    # Create the filename
    filename = f"/Users/rushilgoomer/Desktop/guidance_labs_blogs/posts/{current_date}_{random_word}.html"
    
    # Create a blank html file
    with open(filename, 'w') as file:
        file.write("<!DOCTYPE html>\n<html>\n<head>\n<title>Blank HTML</title>\n</head>\n<body>\n</body>\n</html>")
    
    print(f"Created file: {filename}")

create_blank_html_file()
# Out:
# Created file: /Users/rushilgoomer/Desktop/guidance_labs_blogs/posts/2026-03-26_dswey.html

# %%
# !node build.js
# Out:
# ✓ index.html rebuilt — 3 post(s) listed.

# %%
# 1. Rebuild index.html from posts/
# !node build.js

# 2. Stage everything
# !git add -A
# !git status

# 3. Commit with today's date as the message
import datetime
msg = f"deploy {datetime.date.today()}"
# !git commit -m "{msg}"

# 4. Push to main
# !git push origin main
# Out:
# ✓ index.html rebuilt — 2 post(s) listed.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   deploy.ipynb
#
# [main 8356e8b] deploy 2026-03-26
#  1 file changed, 15 insertions(+), 14 deletions(-)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 564 bytes | 564.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/R-Goomer/guidance_labs_blogs.git
#    32e55d0..8356e8b  main -> main
